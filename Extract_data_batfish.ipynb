# %% [markdown]
# # Extracting data from network config files using batfish.
#
# The code uses batfish to get vendor neutral information about the network. Batfish outputs the data in form of pandas dataframe which are then converted and stored as json files.
#
# ## Requirements:
#  * Batfish tool and pybatfish.
#  Both can be easily installed by following the directions on the [offical github page](https://github.com/batfish/batfish). Few things to keep in mind:
#  * Pyhton version should be >=3.6
#  * Java 8 is required
#  * Use virtual environment to install pybatfish (as mentioned in the documentation).

# %% [markdown]
# Before running the following cells, make sure that the batfish tool is running locally. If you've followed the directions given on the github page, the following command should do it:
# > docker run -v ```$(pwd)/data:/data -p 9997:9997 -p 9996:9996 batfish/allinone```

# %% [markdown]
# The following cell imports pybatfish and other needed packages. If you get a ```ConnectionError```, it probably means that batfish is not running locally. Other than that there's no need to understand any part of it.

# %%
import logging
import random
import os
import collections
import pandas as pd
from IPython.display import display
from pandas.io.formats.style import Styler

from pybatfish.client.commands import *
# noinspection PyUnresolvedReferences
from pybatfish.datamodel import Interface, Edge
from pybatfish.datamodel.flow import HeaderConstraints, PathConstraints
from pybatfish.question import bfq, load_questions  # noqa: F401
from pybatfish.util import get_html

bf_logger.setLevel(logging.WARN)

load_questions()

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
# Prevent rendering text between '$' as MathJax expressions
pd.set_option('display.html.use_mathjax', False)

# UUID for CSS styles used by pandas styler.
# Keeps our notebook HTML deterministic when displaying dataframes
_STYLE_UUID = "pybfstyle"


class MyStyler(Styler):
    """A custom styler for displaying DataFrames in HTML"""

    def __repr__(self):
        return repr(self.data)


def show(df):
    """
    Displays a dataframe as HTML table.

    Replaces newlines and double-spaces in the input with HTML markup, and
    left-aligns the text.
    """

    # workaround for Pandas bug in Python 2.7 for empty frames
    if not isinstance(df, pd.DataFrame) or df.size == 0:
        display(df)
        return
    df = df.replace('\n', '<br>', regex=True).replace('  ', '&nbsp;&nbsp;',
                                                      regex=True)
    display(MyStyler(df).set_uuid(_STYLE_UUID).format(get_html)
            .set_properties(**{'text-align': 'left', 'vertical-align': 'top'}))

# %% [markdown]
# ## The following cell is where batfish analyzes the config files.
# ```NETWORK_NAME``` and ```SNAPSHOT_NAME``` don't matter if you're working with a single network. However, the final json files will be stored in a directory with name ```NETWORK_NAME json files```. The important change you should make is to ```SNAPSHOT_PATH``` which should point to the directory containing your config files. The following setup is to read the [example network](https://github.com/batfish/pybatfish/tree/master/jupyter_notebooks/networks/example) given in the [pybatfish tutorials](https://github.com/batfish/pybatfish/tree/master/jupyter_notebooks).

# %%
NETWORK_NAME = "campus-anon-mixed-vnet2"
SNAPSHOT_NAME = "example_snapshot"

SNAPSHOT_PATH = "networks/campus-anon-mixed-vnet2"

# Now create the network and initialize the snapshot
bf_set_network(NETWORK_NAME)
bf_init_snapshot(SNAPSHOT_PATH, name=SNAPSHOT_NAME, overwrite=True)
load_questions()
# Out:
# One or more input files were not fully recognized by Batfish. Some unrecognized configuration snippets are not uncommon for new networks, and it is often fine to proceed with further analysis. You can help the Batfish developers improve support for your network by running:
#
#     bf_upload_diagnostics(dry_run=False)
#
# to share private, anonymized information. For more information, see the documentation with:
#
#     help(bf_upload_diagnostics)

# %% [markdown]
# Batfish has a property ```namedStrucures()``` which gives the named structures of the network.``` answers().frame()``` is used to get the data in a pandas dataframe.
#
# The column ```Structure_Type``` denotes the type of the named structure(the code will create a json file for each value in the column).
#
#
# The following block will get the named structures in dataframe ```data```.

# %%
data = bfq.namedStructures().answer().frame()

# %%
data
# Out:
#               Node       Structure_Type               Structure_Name  \
# 0     st75hr82      Routing_Policy       MVS_Floating_Address
# 1     rt73sn14m4ce  Route_Filter_List    from-PE
# 2     st73in44p4as  IP_Access_List       98
# 3     st73in59p5as  IP_Access_List       98
# 4     rt55in04hrds  AS_Path_Access_List  93
# 5     st73in45p4as  IP_Access_List       125
# 6     rt73sn14m4ce  IPSec_Policy         RT75SN14HRCE:10
# 7     rt55in70hras  Route_Filter_List    PL-MVS-OCC-INI-EURO-RNI-OUT
# 8     rt73ve11m5ar  IP_Access_List       99
# 9     rt73in04m4ds  IP_Access_List       99
# 10    rt73in05m5ds  AS_Path_Access_List  93
# 11    rt62in83rh    VRF                  default
# 12    rt55in70hras  Community_List       Orange4
# 13    st73in27p4as  IP_Access_List       BRPD_out
# 14    rt55in04hrds  Routing_Policy       to-VE
# 15    rt55in72hrce  IPSec_Proposal       IPSEC
# 16    rt62in82rh    Route_Filter_List    RDH-Loopbacks
# 17    st55in80hras  Routing_Policy       FROM_TPF
# 18    rt75sn14hrce  Route_Filter_List    from-OCB
# 19    rt73sn11m5cr  IP_Access_List       98
# 20    rt55in04hrds  Route_Filter_List    INI-BB-networks
# 21    rt75in73hrce  Community_List       Advertising-OCC-LAN
# 22    st73in29p5as  Route_Filter_List    11
# 23    st75in16hras  Route_Filter_List    16
# 24    rt73in70m4as  Route_Filter_List    Orange2INI
# 25    st73in45p4as  VRF                  default
# 26    st55in80hras  IP_Access_List       11
# 27    rt73ve10m4ar  IP_Access_List       99
# 28    rt75in71hras  AS_Path_Access_List  21
# 29    rt73ve11m5ar  Route_Filter_List    DEX-network
# ...            ...                ...            ...
# 1246  st75in18hras  IP_Access_List       130
# 1247  st73in47p5as  IP_Access_List       99
# 1248  st73in25p4as  VRF                  default
# 1249  rt55in81hrtn  IP_Access_List       115
# 1250  rt73sn15m5ce  Route_Filter_List    from-OCB
# 1251  rt73ve10m4ar  Route_Filter_List    KBH-RNI-CEMEA-networks
# 1252  rt73in70m4as  Routing_Policy       Orange-to-INI
# 1253  rt75in71hras  Community_List       Orange3
# 1254  rt73in08m4ce  IP_Access_List       113
# 1255  st73in23p5as  IP_Access_List       11
# 1256  st73in27p4as  IP_Access_List       120
# 1257  rt73ve11m5ar  IP_Access_List       125
# 1258  rt73sn15m5ce  Route_Filter_List    to-PE
# 1259  rt73in70m4as  Routing_Policy       to-OCLA
# 1260  st73in26p4as  IP_Access_List       120
# 1261  st73in64p5as  IP_Access_List       125
# 1262  rt55in70hras  Route_Filter_List    Orange2INI
# 1263  st73in22p5as  IP_Access_List       11
# 1264  rt55in80hrtn  AS_Path_Access_List  2
# 1265  st75hr82      IP_Access_List       130
# 1266  rt73in05m5ds  VRF                  default
# 1267  rt62bs83      Route_Filter_List    OCB-Ext-networks
# 1268  rt73in70m4as  Routing_Policy       INI-to-DPS_2
# 1269  st73in66p5as  IP_Access_List       125
# 1270  st73in46p5as  IP_Access_List       99
# 1271  st73in65p5as  IP_Access_List       125
# 1272  rt73ve11m5ar  Route_Filter_List    OCB-INI-networks
# 1273  rt62bs82      Route_Filter_List    OCB-Ext-networks
# 1274  st75hr83      VRF                  default
# 1275  rt55in04hrds  Routing_Policy       to-BB
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0     {'name': 'MVS_Floating_Address', 'statements': [{'class': 'org.batfish.datamodel.routing_policy.statement.If', 'comment': '~RMCLAUSE~MVS_Floating_Address~10~', 'falseStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.Statements$StaticStatement', 'type': 'ReturnLocalDefaultAction'}], 'guard': {'class': 'org.batfish.datamodel.routing_policy.expr.MatchPrefixSet', 'prefix': {'class': 'org.batfish.datamodel.routing_policy.expr.DestinationNetwork'}, 'prefixSet': {'class': 'org.batfish.datamodel.routing_policy.expr.NamedPrefixSet', 'name': '11'}}, 'trueStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.Statements$StaticStatement', 'type': 'ReturnTrue'}]}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1     {'lines': [{'action': 'PERMIT', 'ipWildcard': '126.62.66.207', 'lengthRange': '32-32'}, {'action': 'PERMIT', 'ipWildcard': '126.62.182.161', 'lengthRange': '32-32'}], 'name': 'from-PE'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 2     {'name': '98', 'lines': [{'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.172.0.0/14'}}}, 'name': '10 permit ip 126.173.34.41/14 any'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.168.0.0/16'}}}, 'name': '20 permit ip 126.168.136.164/16 any'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.170.0.0/16'}}}, 'name': '30 permit ip 126.170.176.15/16 any'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.171.0.0/16'}}}, 'name': '40 permit ip 126.171.230.136/16 any'}, {'action': 'DENY', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}}}, 'name': '50 deny ip any any'}], 'sourceName': '98', 'sourceType': 'extended ipv4 access-list'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 3     {'name': '98', 'lines': [{'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.172.0.0/14'}}}, 'name': '10 permit ip 126.173.34.41/14 any'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.168.0.0/16'}}}, 'name': '20 permit ip 126.168.136.164/16 any'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.170.0.0/16'}}}, 'name': '30 permit ip 126.170.176.15/16 any'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.171.0.0/16'}}}, 'name': '40 permit ip 126.171.230.136/16 any'}, {'action': 'DENY', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}}}, 'name': '50 deny ip any any'}], 'sourceName': '98', 'sourceType': 'extended ipv4 access-list'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 4     {'lines': [{'action': 'PERMIT', 'regex': '(,|\{|\}|^|$| )64693(,|\{|\}|^|$| )'}], 'name': '93'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 5     {'name': '125', 'lines': [{'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.0.0.0/8'}}}, 'name': '10 permit ip 126.105.145.135/8 any'}], 'sourceName': '125', 'sourceType': 'extended ipv4 access-list'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 6     {'name': 'RT75SN14HRCE:10', 'pfsKeyGroupDynamicIke': False, 'proposals': ['IPSEC']}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 7     {'lines': [{'action': 'PERMIT', 'ipWildcard': '196.1.253.64', 'lengthRange': '32-32'}, {'action': 'PERMIT', 'ipWildcard': '196.1.253.67', 'lengthRange': '32-32'}, {'action': 'PERMIT', 'ipWildcard': '196.1.253.113', 'lengthRange': '32-32'}, {'action': 'PERMIT', 'ipWildcard': '196.1.253.21', 'lengthRange': '32-32'}], 'name': 'PL-MVS-OCC-INI-EURO-RNI-OUT'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 8     {'name': '99', 'lines': [{'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.182.152.234'}}}, 'name': 'permit 126.182.152.234'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.182.155.209'}}}, 'name': 'permit 126.182.155.209'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.183.172.226'}}}, 'name': 'permit 126.183.172.226'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.183.173.231'}}}, 'name': 'permit 126.183.173.231'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.172.0.0/14'}}}, 'name': 'permit 126.173.34.41 0.3.255.255'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.168.0.0/16'}}}, 'name': 'permit 126.168.136.164 0.0.255.255'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.170.0.0/16'}}}, 'name': 'permit 126.170.176.15 0.0.255.255'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '126.171.240.0/20'}}}, 'name': 'permit 126.171.246.80 0.0.15.255'}, {'action': 'DENY', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}, 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}}}, 'name': 'deny any log'}], 'sourceName': '99', 'sourceType': 'standard ipv4 access-list'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# ...
# 1273  {'lines': [{'action': 'PERMIT', 'ipWildcard': '193.93.82.0/24', 'lengthRange': '24-24'}, {'action': 'PERMIT', 'ipWildcard': '193.93.13.0/24', 'lengthRange': '24-24'}, {'action': 'PERMIT', 'ipWildcard': '193.93.12.0/24', 'lengthRange': '24-24'}, {'action': 'PERMIT', 'ipWildcard': '193.93.15.0/24', 'lengthRange': '24-24'}], 'name': 'OCB-Ext-networks'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 1274  {'name': 'default', 'bgpProcess': {'multipathEbgp': False, 'multipathEquivalentAsPathMatchMode': 'EXACT_PATH', 'multipathIbgp': False, 'neighbors': {'126.218.99.128/32': {'class': 'org.batfish.datamodel.BgpActivePeerConfig', 'additionalPathsReceive': False, 'additionalPathsSelectAll': False, 'additionalPathsSend': False, 'advertiseExternal': False, 'advertiseInactive': True, 'allowLocalAsIn': False, 'allowRemoteAsOut': True, 'clusterId': 2128275760, 'defaultMetric': 0, 'ebgpMultihop': False, 'enforceFirstAs': False, 'exportPolicy': '~BGP_PEER_EXPORT_POLICY:default:126.218.99.128~', 'exportPolicySources': ['MVS_Floating_Address'], 'localAs': 64555, 'localIp': '126.218.233.48', 'peerAddress': '126.218.99.128', 'remoteAs': 64555, 'routeReflectorClient': False, 'sendCommunity': True}, '126.218.99.129/32': {'class': 'org.batfish.datamodel.BgpActivePeerConfig', 'additionalPathsReceive': False, 'additionalPathsSelectAll': False, 'additionalPathsSend': False, 'advertiseExternal': False, 'advertiseInactive': True, 'allowLocalAsIn': False, 'allowRemoteAsOut': True, 'clusterId': 2128275760, 'defaultMetric': 0, 'ebgpMultihop': False, 'enforceFirstAs': False, 'exportPolicy': '~BGP_PEER_EXPORT_POLICY:default:126.218.99.129~', 'exportPolicySources': ['MVS_Floating_Address'], 'localAs': 64555, 'localIp': '126.218.233.48', 'peerAddress': '126.218.99.129', 'remoteAs': 64555, 'routeReflectorClient': False, 'sendCommunity': True}}, 'routerId': '126.218.233.48', 'tieBreaker': 'ARRIVAL_ORDER'}, 'interfaces': ['GigabitEthernet1/1', 'GigabitEthernet1/10', 'GigabitEthernet1/11', 'GigabitEthernet1/12', 'GigabitEthernet1/13', 'GigabitEthernet1/14', 'GigabitEthernet1/15', 'GigabitEthernet1/16', 'GigabitEthernet1/17', 'GigabitEthernet1/18', 'GigabitEthernet1/19', 'GigabitEthernet1/2', 'GigabitEthernet1/20', 'GigabitEthernet1/21', 'GigabitEthernet1/22', 'GigabitEthernet1/23', 'GigabitEthernet1/24', 'GigabitEthernet1/25', 'GigabitEthernet1/26', 'GigabitEthernet1/27', 'GigabitEthernet1/28', 'GigabitEthernet1/29', 'GigabitEthernet1/3', 'GigabitEthernet1/30', 'GigabitEthernet1/31', 'GigabitEthernet1/32', 'GigabitEthernet1/33', 'GigabitEthernet1/34', 'GigabitEthernet1/35', 'GigabitEthernet1/36', 'GigabitEthernet1/37', 'GigabitEthernet1/38', 'GigabitEthernet1/39', 'GigabitEthernet1/4', 'GigabitEthernet1/40', 'GigabitEthernet1/41', 'GigabitEthernet1/42', 'GigabitEthernet1/43', 'GigabitEthernet1/44', 'GigabitEthernet1/45', 'GigabitEthernet1/46', 'GigabitEthernet1/47', 'GigabitEthernet1/48', 'GigabitEthernet1/5', 'GigabitEthernet1/6', 'GigabitEthernet1/7', 'GigabitEthernet1/8', 'GigabitEthernet1/9', 'GigabitEthernet2/1', 'GigabitEthernet2/10', 'GigabitEthernet2/11', 'GigabitEthernet2/12', 'GigabitEthernet2/13', 'GigabitEthernet2/14', 'GigabitEthernet2/15', 'GigabitEthernet2/16', 'GigabitEthernet2/17', 'GigabitEthernet2/18', 'GigabitEthernet2/19', 'GigabitEthernet2/2', 'GigabitEthernet2/20', 'GigabitEthernet2/21', 'GigabitEthernet2/22', 'GigabitEthernet2/23', 'GigabitEthernet2/24', 'GigabitEthernet2/25', 'GigabitEthernet2/26', 'GigabitEthernet2/27', 'GigabitEthernet2/28', 'GigabitEthernet2/29', 'GigabitEthernet2/3', 'GigabitEthernet2/30', 'GigabitEthernet2/31', 'GigabitEthernet2/32', 'GigabitEthernet2/33', 'GigabitEthernet2/34', 'GigabitEthernet2/35', 'GigabitEthernet2/36', 'GigabitEthernet2/37', 'GigabitEthernet2/38', 'GigabitEthernet2/39', 'GigabitEthernet2/4', 'GigabitEthernet2/40', 'GigabitEthernet2/41', 'GigabitEthernet2/42', 'GigabitEthernet2/43', 'GigabitEthernet2/44', 'GigabitEthernet2/45', 'GigabitEthernet2/46', 'GigabitEthernet2/47', 'GigabitEthernet2/48', 'GigabitEthernet2/5', 'GigabitEthernet2/6', 'GigabitEthernet2/7', 'GigabitEthernet2/8', 'GigabitEthernet2/9', 'GigabitEthernet5/1', 'GigabitEthernet5/2', 'Loopback3', 'Port-Channel1', ...], 'ospfProcess': {'areas': {'0': {'injectDefaultRoute': True, 'interfaces': ['GigabitEthernet2/1', 'GigabitEthernet2/10', 'GigabitEthernet2/2', 'GigabitEthernet2/5', 'GigabitEthernet2/6', 'GigabitEthernet2/9', 'Lo ...
# 1275  {'name': 'to-BB', 'statements': [{'class': 'org.batfish.datamodel.routing_policy.statement.If', 'comment': '~RMCLAUSE~to-BB~5~', 'falseStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.If', 'comment': '~RMCLAUSE~to-BB~6~', 'falseStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.If', 'comment': '~RMCLAUSE~to-BB~10~', 'falseStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.Statements$StaticStatement', 'type': 'ReturnLocalDefaultAction'}], 'guard': {'class': 'org.batfish.datamodel.routing_policy.expr.MatchPrefixSet', 'prefix': {'class': 'org.batfish.datamodel.routing_policy.expr.DestinationNetwork'}, 'prefixSet': {'class': 'org.batfish.datamodel.routing_policy.expr.NamedPrefixSet', 'name': 'INI-BB-networks'}}, 'trueStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.Statements$StaticStatement', 'type': 'ReturnTrue'}]}], 'guard': {'class': 'org.batfish.datamodel.routing_policy.expr.MatchAsPath', 'expr': {'class': 'org.batfish.datamodel.routing_policy.expr.NamedAsPathSet', 'name': '62'}}, 'trueStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.Statements$StaticStatement', 'type': 'ReturnFalse'}]}], 'guard': {'class': 'org.batfish.datamodel.routing_policy.expr.MatchAsPath', 'expr': {'class': 'org.batfish.datamodel.routing_policy.expr.NamedAsPathSet', 'name': '93'}}, 'trueStatements': [{'class': 'org.batfish.datamodel.routing_policy.statement.Statements$StaticStatement', 'type': 'ReturnFalse'}]}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
#
# [1276 rows x 4 columns]

# %%
Structure_types = list(data.Structure_Type.unique())
for struct in Structure_types:
    
    df = data[data['Structure_Type']==struct]
    
    col_names = list(df.Structure_Name.unique())
    unique_nodes = list(df.Node.unique())
    
    struct_df = pd.DataFrame(index=unique_nodes,columns=col_names)
    
    nodes = df['Node']
    acls = df['Structure_Name']
    values = df['Structure_Definition']
    
    zip_data = zip(nodes,acls,values)
    
    for index,column,value in zip_data:
        struct_df.loc[index,column] = [value]
        
    fileName=str(struct)+".json"
    directory = "./"+str(NETWORK_NAME)+" json files"
    if not os.path.exists(directory):
        os.mkdir(directory)
    fullName = os.path.join(directory, fileName)
    struct_df.to_json(fullName,orient="index") 

print("JSON files saved")
# Out:
# JSON files saved

# %%
df = pd.read_json("campus-anon-net1 json files/IP_Access_List.json")

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               perimeter  \
# allow-internal-management  None
# sshFilter                  [{'name': 'sshFilter', 'lines': [{'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstPorts': ['22-22'], 'ipProtocols': ['TCP'], 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.AclIpSpace', 'lines': [{'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.104'}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.105'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.106'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.250'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.251'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.252'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.253'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.254'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.10.120'}}]}}, {'action': 'PERMIT', 'ipSpace': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.7.150'}}]}}}, 'name': 'allow_ssh'}, {'action': 'DENY', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstPorts': ['22-22'], 'negate': False, 'srcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '0.0.0.0/0'}}}, 'name': 'discard_unknown_ssh'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'negate': False}}, 'name': 'allow'}], 'sourceName': 'sshFilter', 'sourceType': 'firewall filter'}]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    corea  \
# allow-internal-management  [{'name': 'allow-internal-management', 'lines': [{'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'ipProtocols': ['TCP'], 'negate': False, 'srcOrDstPorts': ['22-22']}}, 'name': 'p1'}, {'action': 'DENY', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'dstIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.7.2'}, 'ipProtocols': ['TCP'], 'negate': False, 'srcOrDstPorts': ['22-22', '23-23']}}, 'name': 'p2'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'negate': False}}, 'name': 'p3'}], 'sourceName': 'allow-internal-management', 'sourceType': 'firewall filter'}]
# sshFilter                  None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        coreb
# allow-internal-management  [{'name': 'allow-internal-management', 'lines': [{'action': 'DENY', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'negate': False, 'notSrcIps': {'class': 'org.batfish.datamodel.IpWildcardIpSpace', 'ipWildcard': '130.245.0.0/16'}}}, 'name': 'p1'}, {'action': 'PERMIT', 'matchCondition': {'class': 'org.batfish.datamodel.acl.MatchHeaderSpace', 'headerSpace': {'negate': False}}, 'name': 'p2'}], 'sourceName': 'allow-internal-management', 'sourceType': 'firewall filter'}]
# sshFilter                  None
